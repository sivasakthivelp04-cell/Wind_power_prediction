# %%
# Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('TexasTurbine.csv')

# %%
data
# Out:
#             Time stamp  System power generated | (kW)  Wind speed | (m/s)  \
# 0      Jan 1, 12:00 am                        1766.64               9.926
# 1      Jan 1, 01:00 am                        1433.83               9.273
# 2      Jan 1, 02:00 am                        1167.23               8.660
# 3      Jan 1, 03:00 am                        1524.59               9.461
# 4      Jan 1, 04:00 am                        1384.28               9.184
# ...                ...                            ...                 ...
# 8755  Dec 31, 07:00 pm                        1234.70               8.848
# 8756  Dec 31, 08:00 pm                        1105.37               8.502
# 8757  Dec 31, 09:00 pm                        1405.71               9.224
# 8758  Dec 31, 10:00 pm                        1221.36               8.799
# 8759  Dec 31, 11:00 pm                        1676.77               9.748
#
#       Wind direction | (deg)  Pressure | (atm)  Air temperature | ('C)
# ...

# %%
df=data.dropna()

# %%
df
# Out:
#             Time stamp  System power generated | (kW)  Wind speed | (m/s)  \
# 0      Jan 1, 12:00 am                        1766.64               9.926
# 1      Jan 1, 01:00 am                        1433.83               9.273
# 2      Jan 1, 02:00 am                        1167.23               8.660
# 3      Jan 1, 03:00 am                        1524.59               9.461
# 4      Jan 1, 04:00 am                        1384.28               9.184
# ...                ...                            ...                 ...
# 8755  Dec 31, 07:00 pm                        1234.70               8.848
# 8756  Dec 31, 08:00 pm                        1105.37               8.502
# 8757  Dec 31, 09:00 pm                        1405.71               9.224
# 8758  Dec 31, 10:00 pm                        1221.36               8.799
# 8759  Dec 31, 11:00 pm                        1676.77               9.748
#
#       Wind direction | (deg)  Pressure | (atm)  Air temperature | ('C)
# ...

# %%
df=df.rename({'Time stamp':'Time_stamp','System power generated | (kW)':'System_power_generated',
              'Wind speed | (m/s)':'Wind_speed','Wind direction | (deg)':'Wind_direction','Pressure | (atm)':'Pressure',
              "Air temperature | ('C)":'Air_temperature'},axis=1)

# %%
df.columns
# Out:
# Index(['Time_stamp', 'System_power_generated', 'Wind_speed', 'Wind_direction',
#        'Pressure', 'Air_temperature'],
#       dtype='object')

# %%
df.head()
# Out:
#         Time_stamp  System_power_generated  Wind_speed  Wind_direction  \
# 0  Jan 1, 12:00 am                 1766.64       9.926             128
# 1  Jan 1, 01:00 am                 1433.83       9.273             135
# 2  Jan 1, 02:00 am                 1167.23       8.660             142
# 3  Jan 1, 03:00 am                 1524.59       9.461             148
# 4  Jan 1, 04:00 am                 1384.28       9.184             150
#
#    Pressure  Air_temperature
# 0  1.000480           18.263
# 1  0.999790           18.363
# 2  0.999592           18.663
# 3  0.998309           18.763
# 4  0.998507           18.963

# %%
# Histogram
plt.hist(df['System_power_generated'],color='violet',edgecolor='black')
plt.xlabel('System Power Generation in kW')
plt.ylabel('System Power Generation Levels')
plt.title('Wind Power Generation')
plt.show()

# %%
plt.hist(df['Wind_speed'],bins=9,color='green',edgecolor='black')
plt.xlabel('Wind Speed Level')
plt.ylabel('Wind Speed in m/s')
plt.title('Wind Speed')
# Out:
# Text(0.5, 1.0, 'Wind Speed')

# %%
plt.boxplot(df['Wind_direction'])
plt.show()

# %%
sns.boxplot(df['Pressure'],color='g')
# Out:
# <AxesSubplot:xlabel='Pressure'>

# %%
sns.boxplot(df['Air_temperature'])
plt.show()

# %%
df.hist(figsize=(15,55),layout=(15,4))
plt.show()

# %%
sns.pairplot(df)
plt.show()
